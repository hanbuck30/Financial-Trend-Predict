# %% [markdown]
# <a href="https://colab.research.google.com/github/hanbuck30/capstone-project/blob/main/data_collection_pro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import sklearn
import json
import requests
from io import BytesIO
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler

# %%
# !unzip -qq "/content/drive/MyDrive/BXAI/financial/KR_Data.zip"

# %%
# %cd /content/drive/MyDrive/CodeData/Data/
# Out:
# /content/drive/MyDrive/CodeData/Data

# %%
headers = {'User-Agent': 'Chrome/111.0.0.0 Safari/537.36'}

data = {'mktsel': 'ALL',
        'typeNo': '0',
        'searchText': '',
        'bld': 'dbms/comm/finder/finder_stkisu'}

url = "http://data.krx.co.kr/comm/bldAttendant/getJsonData.cmd"

r = requests.post(url, data=data, headers=headers)
j = json.loads(r.text)

df = pd.json_normalize(j['block1'])
print(len(df))
print(df.iloc[1]['full_code'])
# Out:
# 2711
# KR7095570008

# %%
df
# Out:
#          full_code short_code codeName marketCode marketName marketEngName  \
# 0     KR7060310000     060310       3S        KSQ        코스닥        KOSDAQ
# 1     KR7095570008     095570   AJ네트웍스        STK       유가증권         KOSPI
# 2     KR7006840003     006840    AK홀딩스        STK       유가증권         KOSPI
# 3     KR7054620000     054620      APS        KSQ        코스닥        KOSDAQ
# 4     KR7265520007     265520    AP시스템        KSQ        코스닥        KOSDAQ
# ...            ...        ...      ...        ...        ...           ...
# 2706  KR7000542001     000547  흥국화재2우B        STK       유가증권         KOSPI
# 2707  KR7000541003     000545    흥국화재우        STK       유가증권         KOSPI
# 2708  KR7003280005     003280     흥아해운        STK       유가증권         KOSPI
# 2709  KR7037440005     037440       희림        KSQ        코스닥        KOSDAQ
# 2710  KR7238490007     238490       힘스        KSQ        코스닥        KOSDAQ
#
#      ord1 ord2
# 0           16
# 1           16
# 2           16
# 3           16
# 4           16
# ...   ...  ...
# 2706        16
# 2707        16
# 2708        16
# 2709        16
# 2710        16
#
# [2711 rows x 8 columns]

# %%
df.loc[df['codeName']=='NAVER']
# Out:
#         full_code short_code codeName marketCode marketName marketEngName  \
# 192  KR7035420009     035420    NAVER        STK       유가증권         KOSPI
#
#     ord1 ord2
# 192        16

# %%
for i in range(2711):
    if df.loc[df['codeName']] == '3S':
        print(df['full_code'].values[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-a2853d60b5d1> in <cell line: 1>()
#       1 for i in range(2711):
# ----> 2     if df.loc[df['codeName']] == '3S':
#       3         print(df['full_code'].values[0])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1299                     raise ValueError("Cannot index with multidimensional key")
#    1300
# -> 1301                 return self._getitem_iterable(key, axis=axis)
#    1302
#    1303             # nested tuple slicing
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1237
#    1238         # A collection of keys
# -> 1239         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1240         return self.obj._reindex_with_indexers(
#    1241             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1430         axis_name = self.obj._get_axis_name(axis)
#    1431
# -> 1432         keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1433
#    1434         return keyarr, indexer
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
#    6072         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6128                 if use_interval_msg:
#    6129                     key = list(key)
# -> 6130                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6131
#    6132             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['3S', 'AJ네트웍스', 'AK홀딩스', 'APS', 'AP시스템', 'AP위성', 'BGF', 'BGF리테일',\n       'BGF에코머티리얼즈', 'BNK금융지주',\n       ...\n       '휴젤', '흥구석유', '흥국', '흥국에프엔비', '흥국화재', '흥국화재2우B', '흥국화재우', '흥아해운', '희림',\n       '힘스'],\n      dtype='object', length=2711)] are in the [index]"

# %%
# %cd /content/drive/MyDrive/CodeData/Data/
# Out:
# /content/drive/MyDrive/CodeData/Data

# %%
cnt=0
for i in df['short_code']:
    full_code = df.loc[df['short_code'] == i]['full_code'].values[0]
    
   
    filename="KR%s.csv" %full_code[2:12]
    name="HK%s.csv" %full_code[2:12]
    try:
        globals()["df{}".format(full_code[2:12])] = pd.read_csv(filename)
        #globals()["df{}".format(full_code[2:12])] = pd.read_csv(name)
    except:    # 예외가 발생했을 때 실행됨
        
        #print("HK%s"%full_code[2:12],"이 데이터는 없어요")
        cnt+=1
   

print(cnt)
# Out:
# 243

# %%
df7035420009.head()
# Out:
#        TRD_DD  ISU_CD ISU_NM TDD_CLSPRC TDD_OPNPRC TDD_HGPRC TDD_LWPRC  \
# 0  2022/01/11   35420  NAVER    335,000    336,000   344,500   334,500
# 1  2022/01/10   35420  NAVER    335,000    339,000   339,500   329,000
# 2  2022/01/07   35420  NAVER    338,000    338,000   343,500   337,000
# 3  2022/01/06   35420  NAVER    338,500    348,500   349,500   337,500
# 4  2022/01/05   35420  NAVER    355,000    362,000   362,000   352,000
#
#                MKTCAP ACC_TRDVOL    EPS    PER     BPS   PBR  DPS DVD_YLD
# 0  54,956,443,475,000    805,084  6,877  48.71  44,850  7.47  402    0.12
# 1  54,956,443,475,000    828,611  6,877  48.71  44,850  7.47  402    0.12
# 2  55,448,590,730,000    787,839  6,877  49.15  44,850  7.54  402    0.12
# 3  55,530,615,272,500  1,280,916  6,877  49.22  44,850  7.55  402    0.12
# 4  58,237,425,175,000  1,151,703  6,877  51.62  44,850  7.92  402    0.11

# %%
# %cd /content/drive/MyDrive/CodeData/capstone
# Out:
# /content/drive/MyDrive/CodeData/capstone

# %%
cnt=0
for i in df['short_code']:
    full_code = df.loc[df['short_code'] == i]['full_code'].values[0]
    
   
    filename="KR%s.csv" %full_code[2:12]
    name="HK%s.csv" %full_code[2:12]
    try:
        #globals()["fd{}".format(full_code[2:12])] = pd.read_csv(filename)
        globals()["fd{}".format(full_code[2:12])] = pd.read_csv(name)
    except:    # 예외가 발생했을 때 실행됨
        
        #print("HK%s"%full_code[2:12],"이 데이터는 없어요")
        cnt+=1
   

print(cnt)
# Out:
# 0

# %%
fd7035420009.tail()
# Out:
#      Unnamed: 0      TRD_DD TDD_CLSPRC  FLUC_TP_CD CMPPREVDD_PRC  FLUC_RT  \
# 321         321  2022/01/18    338,000           2        -5,500    -1.60
# 322         322  2022/01/17    343,500           1         1,500     0.44
# 323         323  2022/01/14    342,000           2        -6,000    -1.72
# 324         324  2022/01/13    348,000           1         2,500     0.72
# 325         325  2022/01/12    345,500           1        10,500     3.13
#
#     TDD_OPNPRC TDD_HGPRC TDD_LWPRC ACC_TRDVOL       ACC_TRDVAL  \
# 321    346,500   348,000   335,500    441,573  150,023,889,000
# 322    340,500   346,500   339,500    418,789  143,603,981,500
# 323    341,000   342,500   335,500    504,907  171,403,540,000
# 324    348,000   352,000   344,000    677,226  236,322,868,506
# 325    339,500   352,500   339,500  1,047,713  364,057,951,000
#
#                  MKTCAP    LIST_SHRS
# 321  55,448,590,730,000  164,049,085
# 322  56,350,860,697,500  164,049,085
# 323  56,104,787,070,000  164,049,085
# 324  57,089,081,580,000  164,049,085
# 325  56,678,958,867,500  164,049,085

# %%
fd=pd.concat([fd7035420009,df7035420009])
fd =fd.drop(['Unnamed: 0'] ,axis=1)

# %%
fd
# Out:
#           TRD_DD TDD_CLSPRC  FLUC_TP_CD CMPPREVDD_PRC  FLUC_RT TDD_OPNPRC  \
# 0     2023/05/09    211,000         1.0         4,000     1.93    209,000
# 1     2023/05/08    207,000         1.0        10,900     5.56    200,500
# 2     2023/05/04    196,100         1.0         3,500     1.82    191,100
# 3     2023/05/03    192,600         2.0          -600    -0.31    191,800
# 4     2023/05/02    193,200         1.0           900     0.47    192,200
# ...          ...        ...         ...           ...      ...        ...
# 4746  2002/11/04     41,700         NaN           NaN      NaN     43,500
# 4747  2002/11/01     43,900         NaN           NaN      NaN     48,000
# 4748  2002/10/31     46,800         NaN           NaN      NaN     50,000
# 4749  2002/10/30     49,250         NaN           NaN      NaN     49,250
# 4750  2002/10/29     44,000         NaN           NaN      NaN     44,000
#
#      TDD_HGPRC TDD_LWPRC ACC_TRDVOL       ACC_TRDVAL              MKTCAP  \
# 0      214,500   208,500  1,855,368  393,084,585,750  34,614,356,935,000
# 1      207,500   198,200  2,034,862  414,445,311,500  33,958,160,595,000
# 2      197,300   189,000    900,385  174,279,721,400  32,170,025,568,500
# 3      193,400   191,300    448,203   86,298,657,062  31,595,853,771,000
# 4      193,200   191,400    491,178   94,522,112,300  31,694,283,222,000
# ...        ...       ...        ...              ...                 ...
# 4746    43,800    40,650    692,165              NaN     310,124,985,000
# 4747    49,500    42,200    750,761              NaN     326,486,495,000
# 4748    51,200    45,650  1,320,880              NaN     348,053,940,000
# 4749    49,250    48,700    853,638              NaN     366,274,712,500
# 4750    44,000    44,000     20,549              NaN     327,230,200,000
#
#         LIST_SHRS   ISU_CD ISU_NM  EPS    PER  BPS  PBR  DPS DVD_YLD
# 0     164,049,085      NaN    NaN  NaN    NaN  NaN  NaN  NaN     NaN
# 1     164,049,085      NaN    NaN  NaN    NaN  NaN  NaN  NaN     NaN
# 2     164,049,085      NaN    NaN  NaN    NaN  NaN  NaN  NaN     NaN
# 3     164,049,085      NaN    NaN  NaN    NaN  NaN  NaN  NaN     NaN
# 4     164,049,085      NaN    NaN  NaN    NaN  NaN  NaN  NaN     NaN
# ...           ...      ...    ...  ...    ...  ...  ...  ...     ...
# 4746          NaN  35420.0  엔에이치엔  552  75.54    -    -    -       -
# 4747          NaN  35420.0  엔에이치엔  552  79.53    -    -    -       -
# 4748          NaN  35420.0  엔에이치엔  552  84.78    -    -    -       -
# 4749          NaN  35420.0  엔에이치엔  552  89.22    -    -    -       -
# 4750          NaN  35420.0  엔에이치엔  552  79.71    -    -    -       -
#
# [5077 rows x 20 columns]

# %%
# %cd /content/drive/MyDrive
fd.to_csv("naver.csv")
# Out:
# /content/drive/MyDrive

# %%
fdc=fd.columns
fdc=fdc.drop(['TRD_DD', 'FLUC_TP_CD', 'CMPPREVDD_PRC', 'FLUC_RT'])
fdc
# Out:
# Index(['TDD_CLSPRC', 'TDD_OPNPRC', 'TDD_HGPRC', 'TDD_LWPRC', 'ACC_TRDVOL',
#        'ACC_TRDVAL', 'MKTCAP', 'LIST_SHRS', 'ISU_CD', 'ISU_NM', 'EPS', 'PER',
#        'BPS', 'PBR', 'DPS', 'DVD_YLD'],
#       dtype='object')

# %%
pd.to_numeric(fd['TDD_CLSPRC'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "211,000"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-146-741dc9afc49a> in <cell line: 1>()
# ----> 1 pd.to_numeric(fd['TDD_CLSPRC'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     183         coerce_numeric = errors not in ("ignore", "raise")
#     184         try:
# --> 185             values, _ = lib.maybe_convert_numeric(
#     186                 values, set(), coerce_numeric=coerce_numeric
#     187             )
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "211,000" at position 0

# %%
fd=fd.astype({'TDD_CLSPRC':'float','TDD_OPNPRC':'float','TDD_HGPRC':'float','TDD_LWPRC':'float','ACC_TRDVOL':'float','MKTCAP':'float'})
fd
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-136-04d6831bb5f3> in <cell line: 1>()
# ----> 1 fd=fd.astype({'TDD_CLSPRC':'float','TDD_OPNPRC':'float','TDD_HGPRC':'float','TDD_LWPRC':'float','ACC_TRDVOL':'float','MKTCAP':'float'})
#       2 fd
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6224                     res_col = col.copy() if copy else col
#    6225                 else:
# -> 6226                     res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    6227                 results.append(res_col)
#    6228
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
#     450     def convert(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     350                     applied = b.apply(f, **kwargs)
#     351                 else:
# --> 352                     applied = getattr(b, f)(**kwargs)
#     353             except (TypeError, NotImplementedError):
#     354                 if not ignore_failures:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     524         values = self.values
#     525
# --> 526         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     527
#     528         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_array_safe(values, dtype, copy, errors)
#     297
#     298     try:
# --> 299         new_values = astype_array(values, dtype, copy=copy)
#     300     except (ValueError, TypeError):
#     301         # e.g. astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_array(values, dtype, copy)
#     228
#     229     else:
# --> 230         values = astype_nansafe(values, dtype, copy=copy)
#     231
#     232     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_nansafe(arr, dtype, copy, skipna)
#     168     if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169         # Explicit copy, or required since NumPy can't view from / to object.
# --> 170         return arr.astype(dtype, copy=True)
#     171
#     172     return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '211,000'

# %%
scaler=MinMaxScaler()
fd['TDD_OPNPRC'][1]
# Out:
# 1    200,500
# 1    339,000
# Name: TDD_OPNPRC, dtype: object

# %%
scaler=MinMaxScaler()
for i in fdc:
    scaler.fit(fd[i])
    fd[i]=scaler.transform(i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-132-c5bc704487c2> in <cell line: 2>()
#       1 scaler=MinMaxScaler()
#       2 for i in fdc:
# ----> 3     scaler.fit(fd[i])
#       4     fd[i]=scaler.transform(i)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#     425         # Reset internal state before fitting
#     426         self._reset()
# --> 427         return self.partial_fit(X, y)
#     428
#     429     def partial_fit(self, X, y=None):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y)
#     464
#     465         first_pass = not hasattr(self, "n_samples_seen_")
# --> 466         X = self._validate_data(
#     467             X,
#     468             reset=first_pass,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     563             raise ValueError("Validation should be done on X, y or both.")
#     564         elif not no_val_X and no_val_y:
# --> 565             X = check_array(X, input_name="X", **check_params)
#     566             out = X
#     567         elif no_val_X and not no_val_y:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877                     array = xp.astype(array, dtype, copy=False)
#     878                 else:
# --> 879                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880             except ComplexWarning as complex_warning:
#     881                 raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py in _asarray_with_order(array, dtype, order, copy, xp)
#     183     if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184         # Use NumPy API to support order
# --> 185         array = numpy.asarray(array, order=order, dtype=dtype)
#     186         return xp.asarray(array, copy=copy)
#     187     else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __array__(self, dtype)
#     891               dtype='datetime64[ns]')
#     892         """
# --> 893         return np.asarray(self._values, dtype)
#     894
#     895     # ----------------------------------------------------------------------
#
# ValueError: could not convert string to float: '209,000'
